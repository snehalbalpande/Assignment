# %%
1. What does RGBA stand for?

ANS :-RGBA stand for:- Red-Green-Blue-Alpha

# %%
2. From the Pillow module, how do you get the RGBA value of any images?


ANS:- A function call to ImageColor('color_name', 'RGBA')will return the RGBA value for that color

# %%
from PIL import ImageColor
ImageColor.getcolor('red', 'RGBA')
# Out:
# (255, 0, 0, 255)

# %%
ImageColor.getcolor('Black', 'RGBA')
# Out:
# (0, 0, 0, 255)

# %%
ImageColor.getcolor('chocolate', 'RGBA')
# Out:
# (210, 105, 30, 255)

# %%
3. What is a box tuple, and how does it work?

ANS:- A box tuple is a value of fouur integers: the left-edge x-coordinate, the top-rdge y-coordinate, the widh,
    and theheight, repectively.

# %%
4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

ANS:-

# %%
from PIL import Image
img = Image.open('Boston img.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x281FC869DF0>

# %%
img.size
# Out:
# (900, 600)

# %%
5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

ANS:- imgObj.crop((0,50,50,50))

# %%
6. After making changes to an Image object, how could you save it as an image file?

ANS:- Call the imageObj.save('new_filename.png') method of the image object.

# %%
7. What module contains Pillow’s shape-drawing code?

ANS:- The ImageDraw module contains code to draw on images.

# %%
8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

ANS:- ImageDraw objects have shape-drawing method such as point(), line(), or rectangle(). They returned by passing the 
    Image object to the ImageDraw.Draw() function.
